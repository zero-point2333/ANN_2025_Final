# %%
from groundingdino.util.inference import load_model, load_image, predict, annotate
import cv2

model = load_model("groundingdino/config/GroundingDINO_SwinT_OGC.py", "../04-06-segment-anything/weights/groundingdino_swint_ogc.pth")
IMAGE_PATH = ".asset/cat_dog.jpeg"
TEXT_PROMPT = "chair . person . dog ."
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)
cv2.imwrite("annotated_image.jpg", annotated_frame)
# Out:
# [i 1216 18:34:36.049877 84 lock.py:85] Create lock file:/home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/jittor.lock
# [i 1216 18:34:36.063317 84 compiler.py:956] Jittor(1.3.10.0) src: /home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor
# [i 1216 18:34:36.069785 84 compiler.py:957] g++ at /usr/bin/g++(13.3.0)
# [i 1216 18:34:36.069861 84 compiler.py:958] cache_path: /home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default
# [i 1216 18:34:38.016904 84 install_cuda.py:96] cuda_driver_version: [12, 7]
# Downloading https://cg.cs.tsinghua.edu.cn/jittor/assets/cuda12.2_cudnn8_linux.tgz to /home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux.tgz
# 5.61GB [22:18, 4.50MB/s]
# [i 1216 18:58:00.045930 84 __init__.py:412] Found /home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux/bin/nvcc(12.2.140) at /home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux/bin/nvcc.
# [i 1216 18:58:00.264421 84 __init__.py:412] Found gdb(15.0.50) at /usr/bin/gdb.
# [i 1216 18:58:00.286200 84 __init__.py:412] Found addr2line(2.42) at /usr/bin/addr2line.
# [i 1216 18:58:00.476348 84 compiler.py:1013] cuda key:cu12.2.140
# [i 1216 18:58:00.562624 84 compiler.py:34] Create cache dir: /home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default/cu12.2.140
# [i 1216 18:58:00.562970 84 compiler.py:34] Create cache dir: /home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default/cu12.2.140/jit
# [i 1216 18:58:00.563128 84 compiler.py:34] Create cache dir: /home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default/cu12.2.140/obj_files
# [i 1216 18:58:00.563266 84 compiler.py:34] Create cache dir: /home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default/cu12.2.140/gen
# [i 1216 18:58:00.563436 84 compiler.py:34] Create cache dir: /home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default/cu12.2.140/tmp
# [i 1216 18:58:00.563586 84 compiler.py:34] Create cache dir: /home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default/cu12.2.140/checkpoints
# [i 1216 18:58:04.465651 68 log.cc:351] Load log_sync: 1
# [i 1216 18:58:12.198380 68 __init__.py:227] Total mem: 7.35GB, using 2 procs for compiling.
# Compiling jittor_core(56/151) used: 31.575s eta: 53.565s
# In file included from /home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux/include/cuda_runtime.h:82,
#                  from <command-line>:
# /home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux/include/crt/host_config.h:143:2: error: #error -- unsupported GNU version! gcc versions later than 12 are not supported! The nvcc flag '-allow-unsupported-compiler' can be used to override this version check; however, using an unsupported host compiler may cause compilation failure or incorrect run time execution. Use at your own risk.
#   143 | #error -- unsupported GNU version! gcc versions later than 12 are not supported! The nvcc flag '-allow-unsupported-compiler' can be used to override this version check; however, using an unsupported host compiler may cause compilation failure or incorrect run time execution. Use at your own risk.
#       |  ^~~~~
# [w 1216 18:58:44.653086 68 log.cc:416]
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Dear user, your nvcc and gcc version are not match,
# but you can hot fix it by this command:
# >>> sudo python3 -c 's=open("/home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux/include/crt/host_config.h","r").read().replace("#error", "//#error");open("/home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux/include/crt/host_config.h","w").write(s)'
# Compiling jittor_core(58/151) used: 32.250s eta: 51.711s
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor_utils/__init__.py", line 197, in do_compile
#     return cc.cache_compile(cmd, cache_path, jittor_path)
# RuntimeError: [f 1216 18:58:44.654308 68 log.cc:608] Check failed ret(256) == 0(0) Run cmd failed: "/home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux/bin/nvcc"  "/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/src/misc/nan_checker.cu"     -std=c++14 -Xcompiler -fPIC  -Xcompiler -march=native  -Xcompiler -fdiagnostics-color=always   -I"/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/src"  -I"/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/extern" -I/home/caiyc05/miniconda3/envs/jittor_env/include/python3.8 -I/home/caiyc05/miniconda3/envs/jittor_env/include/python3.8 -DHAS_CUDA -DIS_CUDA -I"/home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux/include" -I"/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/extern/cuda/inc"   -I"/home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default/cu12.2.140"   -O2   -c -o "/home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default/cu12.2.140/obj_files/nan_checker.cu.o" -x cu --cudart=shared -ccbin="/usr/bin/g++"   -w  -I"/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/extern/cuda/inc"
# """
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from groundingdino.util.inference import load_model, load_image, predict, annotate
#       2 import cv2
#       4 model = load_model("groundingdino/config/GroundingDINO_SwinT_OGC.py", "../04-06-segment-anything/weights/groundingdino_swint_ogc.pth")
#
# File /mnt/e/3.1/artificial neutral network/final_project/ANN_2025_Final/GroundingDINO/groundingdino/util/inference.py:8
#       6 from PIL import Image
#       7 import bisect
# ----> 8 import jittor as jt
#      10 import groundingdino.datasets.transforms as T
#      11 from groundingdino.models import build_model
#
# File ~/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/__init__.py:18
#      16 ori_float = float
#      17 ori_bool = bool
# ---> 18 from . import compiler
#      19 from .compiler import LOG, has_cuda
#      20 from .compiler import compile_custom_ops, compile_custom_op
#
# File ~/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/compiler.py:1374
#    1370     files = [f for f in files
#    1371         if "__data__" not in f or "src" in f.split("__data__")[1]]
#    1373 cc_flags += f" -l\"jit_utils_core{lib_suffix}\" "
# -> 1374 compile(cc_path, cc_flags+opt_flags, files, 'jittor_core'+extension_suffix)
#    1375 cc_flags += f" -l\"jittor_core{lib_suffix}\" "
#    1377 # TODO: move to compile_extern.py
#    1378 # compile_extern()
#
# File ~/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/compiler.py:151, in compile(compiler, flags, inputs, output, combind_build, cuda_flags, obj_dirname)
#     149             cmd = cmd.replace("-Ofast", "-O2")
#     150     cmds.append(cmd)
# --> 151 jit_utils.run_cmds(cmds, cache_path, jittor_path, "Compiling "+base_output)
#     152 obj_files += ex_obj_files
#     153 if os.name == 'nt':
#
# File ~/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor_utils/__init__.py:251, in run_cmds(cmds, cache_path, jittor_path, msg)
#     249     n = len(cmds)
#     250     dp = DelayProgress(msg, n)
# --> 251     for i,_ in enumerate(p.imap_unordered(do_compile, cmds)):
#     252         dp.update(i)
#     253 finally:
#
# File ~/miniconda3/envs/jittor_env/lib/python3.8/multiprocessing/pool.py:868, in IMapIterator.next(self, timeout)
#     866 if success:
#     867     return value
# --> 868 raise value
#
# RuntimeError: [f 1216 18:58:44.654308 68 log.cc:608] Check failed ret(256) == 0(0) Run cmd failed: "/home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux/bin/nvcc"  "/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/src/misc/nan_checker.cu"     -std=c++14 -Xcompiler -fPIC  -Xcompiler -march=native  -Xcompiler -fdiagnostics-color=always   -I"/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/src"  -I"/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/extern" -I/home/caiyc05/miniconda3/envs/jittor_env/include/python3.8 -I/home/caiyc05/miniconda3/envs/jittor_env/include/python3.8 -DHAS_CUDA -DIS_CUDA -I"/home/caiyc05/.cache/jittor/jtcuda/cuda12.2_cudnn8_linux/include" -I"/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/extern/cuda/inc"   -I"/home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default/cu12.2.140"   -O2   -c -o "/home/caiyc05/.cache/jittor/jt1.3.10/g++13.3.0/py3.8.20/Linux-5.15.167x3c/AMDRyzen97945Hx26/69ce/default/cu12.2.140/obj_files/nan_checker.cu.o" -x cu --cudart=shared -ccbin="/usr/bin/g++"   -w  -I"/home/caiyc05/miniconda3/envs/jittor_env/lib/python3.8/site-packages/jittor/extern/cuda/inc"
