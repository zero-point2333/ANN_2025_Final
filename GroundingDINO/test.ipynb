# %%
from groundingdino.util.inference import load_model, load_image, predict, annotate
import cv2

model = load_model("groundingdino/config/GroundingDINO_SwinT_OGC.py", "weights/groundingdino_swint_ogc.pth")
IMAGE_PATH = ".asset/cat_dog.jpeg"
TEXT_PROMPT = "chair . person . dog ."
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

image_source, image = load_image(IMAGE_PATH)

boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)
cv2.imwrite("annotated_image.jpg", annotated_frame)
# Out:
# [i 1125 21:48:34.345735 92 log.cc:351] Load log_sync: 1
# [i 1125 21:48:34.388084 92 compiler.py:955] Jittor(1.3.7.15) src: /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor
# [i 1125 21:48:34.394741 92 compiler.py:956] g++ at /usr/bin/g++(13.3.0)
# [i 1125 21:48:34.395522 92 compiler.py:957] cache_path: /home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default
# [i 1125 21:48:34.494903 92 __init__.py:411] Found /usr/local/cuda/bin/nvcc(13.0.88) at /usr/local/cuda/bin/nvcc.
# [i 1125 21:48:34.634477 92 __init__.py:411] Found gdb(15.0.50) at /usr/bin/gdb.
# [i 1125 21:48:34.645656 92 __init__.py:411] Found addr2line(2.42) at /usr/bin/addr2line.
# [i 1125 21:48:34.730230 92 compiler.py:1010] cuda key:cu13.0.88
# [i 1125 21:48:35.182065 92 __init__.py:227] Total mem: 7.57GB, using 2 procs for compiling.
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/ops/tape_op.h:12,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/grad.h:7,
#                  from /home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88/gen/pyjt_grad.cc:6:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88/gen/pyjt_var_slices.cc:1:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor_utils/__init__.py", line 197, in do_compile
#     return cc.cache_compile(cmd, cache_path, jittor_path)
# RuntimeError: [f 1125 21:48:35.990828 92 log.cc:608] Check failed ret(256) == 0(0) Run cmd failed: "/usr/bin/g++" "/home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88/gen/pyjt_grad.cc"   -Wall -Wno-unknown-pragmas -std=c++14 -fPIC  -march=native  -fdiagnostics-color=always   -I"/home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src" -I/home/zero-point_/miniconda3/envs/annfinal/include/python3.8 -I/home/zero-point_/miniconda3/envs/annfinal/include/python3.8 -DHAS_CUDA -DIS_CUDA -I"/usr/local/cuda/include" -I"/home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc"   -I"/home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88"   -O2   -c -o "/home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88/obj_files/pyjt_grad.cc.o"
# """
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from groundingdino.util.inference import load_model, load_image, predict, annotate
#       2 import cv2
#       4 model = load_model("groundingdino/config/GroundingDINO_SwinT_OGC.py", "weights/groundingdino_swint_ogc.pth")
#
# File ~/Documents/ANN2025Fall/Final/ANN_2025_Final/GroundingDINO/groundingdino/util/inference.py:8
#       6 from PIL import Image
#       7 import bisect
# ----> 8 import jittor as jt
#      10 import groundingdino.datasets.transforms as T
#      11 from groundingdino.models import build_model
#
# File ~/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/__init__.py:18
#      16 ori_float = float
#      17 ori_bool = bool
# ---> 18 from . import compiler
#      19 from .compiler import LOG, has_cuda
#      20 from .compiler import compile_custom_ops, compile_custom_op
#
# File ~/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/compiler.py:1353
#    1349     files = [f for f in files
#    1350         if "__data__" not in f or "src" in f.split("__data__")[1]]
#    1352 cc_flags += f" -l\"jit_utils_core{lib_suffix}\" "
# -> 1353 compile(cc_path, cc_flags+opt_flags, files, 'jittor_core'+extension_suffix)
#    1354 cc_flags += f" -l\"jittor_core{lib_suffix}\" "
#    1356 # TODO: move to compile_extern.py
#    1357 # compile_extern()
#
# File ~/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/compiler.py:151, in compile(compiler, flags, inputs, output, combind_build, cuda_flags, obj_dirname)
#     149             cmd = cmd.replace("-Ofast", "-O2")
#     150     cmds.append(cmd)
# --> 151 jit_utils.run_cmds(cmds, cache_path, jittor_path, "Compiling "+base_output)
#     152 obj_files += ex_obj_files
#     153 if os.name == 'nt':
#
# File ~/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor_utils/__init__.py:251, in run_cmds(cmds, cache_path, jittor_path, msg)
#     249     n = len(cmds)
#     250     dp = DelayProgress(msg, n)
# --> 251     for i,_ in enumerate(p.imap_unordered(do_compile, cmds)):
#     252         dp.update(i)
#     253 finally:
#
# File ~/miniconda3/envs/annfinal/lib/python3.8/multiprocessing/pool.py:868, in IMapIterator.next(self, timeout)
#     866 if success:
#     867     return value
# --> 868 raise value
#
# RuntimeError: [f 1125 21:48:35.990828 92 log.cc:608] Check failed ret(256) == 0(0) Run cmd failed: "/usr/bin/g++" "/home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88/gen/pyjt_grad.cc"   -Wall -Wno-unknown-pragmas -std=c++14 -fPIC  -march=native  -fdiagnostics-color=always   -I"/home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src" -I/home/zero-point_/miniconda3/envs/annfinal/include/python3.8 -I/home/zero-point_/miniconda3/envs/annfinal/include/python3.8 -DHAS_CUDA -DIS_CUDA -I"/usr/local/cuda/include" -I"/home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc"   -I"/home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88"   -O2   -c -o "/home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88/obj_files/pyjt_grad.cc.o"
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/core.h:11,
#                  from /home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88/gen/pyjt_core.cc:6:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/misc/miniz.h:165,
#                  from /home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88/gen/pyjt_miniz.cc:6:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/init.cc:9:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/mem/allocator/cuda_dual_allocator.h:13,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/mem/allocator.cc:14:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/memory_profiler.cc:12:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88/gen/jit_op_maker.h:5,
#                  from /home/zero-point_/.cache/jittor/jt1.3.7/g++13.3.0/py3.8.20/Linux-6.6.87.2x00/13thGenIntelRCx56/default/cu13.0.88/gen/pyjt_jit_op_maker.cc:6:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/ops/tape_op.h:12,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/grad.h:7,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/grad.cc:8:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.cc:10:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.cc:20:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/type/fp16_compute.h: In constructor ‘jittor::float16::float16(jittor::float32)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/type/fp16_compute.h:126:24: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#   126 |         unsigned x = *((int*)(void*)(&f));
#       |                       ~^~~~~~~~~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/type/fp16_compute.h: In member function ‘jittor::float16::operator float() const’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/type/fp16_compute.h:204:41: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#   204 |         return reinterpret_cast<float&>(temp);
#       |                                         ^~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/op.cc:17:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/parallel_compiler.cc:17:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/graph.cc:10:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/opt/pass/assume_aligned_pass.cc:13:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/mem/allocator/cuda_host_allocator.cc:9:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/mem/mem_info.cc:25:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/mem/mem_info.cc: In constructor ‘jittor::MemInfo::MemInfo()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/mem/mem_info.cc:286:11: warning: unused variable ‘all_total’ [-Wunused-variable]
#   286 |     int64 all_total = 0, gpu_total = 0, cpu_total = 0;
#       |           ^~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/mem/allocator/cuda_managed_allocator.cc:9:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/mem/allocator/cuda_device_allocator.cc:10:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/mem/allocator/cuda_dual_allocator.h:13,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/mem/allocator/cuda_dual_allocator.cc:9:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/ops/fetch_op.cc:11:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/ops/array_op.cc:9:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
# ...
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/pyjt/py_ring_buffer.cc:11:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/pyjt/py_array_op.cc:9:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/core.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/pybind/core.cc:7:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.h:15,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/var_holder.h:11,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/misc/miniz.h:165,
#                  from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/misc/miniz.cc:27:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/misc/nan_checker.cc:13:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h(263): error: class "cudaDeviceProp" has no member "computeMode"
#     if (deviceProp.computeMode == cudaComputeModeProhibited) {
#                    ^
#
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h(307): error: class "cudaDeviceProp" has no member "computeMode"
#       if (deviceProp.computeMode != cudaComputeModeProhibited) {
#                      ^
#
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h(316): error: class "cudaDeviceProp" has no member "clockRate"
#                                 sm_per_multiproc * deviceProp.clockRate;
#                                                               ^
#
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h(391): error: class "cudaDeviceProp" has no member "computeMode"
#           (deviceProp.computeMode != cudaComputeModeProhibited)) {
#                       ^
#
# 4 errors detected in the compilation of "/home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/misc/nan_checker.cu".
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/profiler/profiler.cc:18:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
# In file included from /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/src/executor.cc:15:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuDeviceInit(int)’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:263:18: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   263 |   if (deviceProp.computeMode == cudaComputeModeProhibited) {
#       |                  ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int gpuGetMaxGflopsDeviceId()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:307:20: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   307 |     if (deviceProp.computeMode != cudaComputeModeProhibited) {
#       |                    ^~~~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:316:61: error: ‘struct cudaDeviceProp’ has no member named ‘clockRate’
#   316 |                               sm_per_multiproc * deviceProp.clockRate;
#       |                                                             ^~~~~~~~~
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h: In function ‘int findIntegratedGPU()’:
# /home/zero-point_/miniconda3/envs/annfinal/lib/python3.8/site-packages/jittor/extern/cuda/inc/helper_cuda.h:391:21: error: ‘struct cudaDeviceProp’ has no member named ‘computeMode’
#   391 |         (deviceProp.computeMode != cudaComputeModeProhibited)) {
#       |                     ^~~~~~~~~~~
